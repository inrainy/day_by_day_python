# %% [markdown]
# #스택 문제
#
# • 정수를 저장하는 스택을 구현한 다음, 입력으로 주어지는 명령을 처리하는 프로그램을 작성하시오.
#
# • 명령은 총 다섯 가지이다.
#
# • push X: 정수 X를 스택에 넣는 연산이다.
#
# • pop: 스택에서 가장 위에 있는 정수를 빼고, 그 수를 출력한다. 만약 스택에 들어있는 정수가 없는 경우에는 -1
# 을 출력한다.
#
# • size: 스택에 들어있는 정수의 개수를 출력한다.
#
# • empty: 스택이 비어있으면 1, 아니면 0을 출력한다.
#
# • top: 스택의 가장 위에 있는 정수를 출력한다. 만약 스택에 들어있는 정수가 없는 경우에는 -1을 출력한다.

# %% [markdown]
# • 첫째 줄에 주어지는 명령의 수 N (1 ≤ N ≤ 10,000)이 주어진다. 둘째 줄부터 N개의 줄에
# 는 명령이 하나씩 주어진다. 주어지는 정수는 1보다 크거나 같고, 100,000보다 작거나 같
# 다. 문제에 나와있지 않은 명령이 주어지는 경우는 없다.
#
# • 출력해야하는 명령이 주어질 때마다, 한 줄에 하나씩 출력한다

# %%
#일단 틀을 주셨는데 안써도 상관없음

def process_stack(command):
    stack_list = []
    stack_size = 0
 
n = int(input()) 
for _ in range(n): 
 command = input().split(" ") 
 process_stack(command)

# 왜 pass를 쓰는건지 괄호안에 command가 들어가는 이유가 궁금함
# Out:
# 7
# pop
# top
# push 123
# top
# pop
# top
# pop

# %%
def stack(command):
  global stack_list

  if command[0] == 'push':
    stack_list.append(command[1])

  if command[0] == 'pop':
    if len(stack_list) == 0:
      print('-1')
    else:
      print(stack_list[-1])
      del stack_list[-1]

  if command[0] == 'size':
    print(len(stack_list))

  if command[0] =='empty':
    if len(stack_list) == 0:
      print('1')
    else:
      print('0')

  if command[0] =='top':
    if len(stack_list) == 0:
      print('-1')
    else:
      print(stack_list[-1])


n = int(input())
stack_list = []

for i in range(n):
  command = input().split(" ")
  #스플릿 해주면 자동으로 command가 리스트 형식으로 입력됨
  stack(command)
# Out:
# 14
# push 1
# push 2
# top
# 2
# size
# 2
# empty
# 0
# pop
# 2
# pop
# 1
# pop
# -1
# size
# 0
# empty
# 1
# pop
# -1
# push 3
# empty
# 0
# top
# 3

# %%
#연습

def stack(command):


print(stack(command))
print(stack(asd))

# %%
#연습

def stack():

# %%
#연습


print(stack(asd))

# %%
#글로벌 - 전역변수가 없다는 가정하에

def stack(command):

  if command[0] == 'push':
    stack_list.append(command[1])

  if command[0] == 'pop':
    if len(stack_list) == 0:
      print('-1')
    else:
      print(stack_list[-1])
      del stack_list[-1]

  if command[0] == 'size':
    print(len(stack_list))

  if command[0] =='empty':
    if len(stack_list) == 0:
      print('1')
    else:
      print('0')

  if command[0] =='top':
    if len(stack_list) == 0:
      print('-1')
    else:
      print(stack_list[-1])


n = int(input())
stack_list = []

for i in range(n):
  command = input().split(" ")
  #스플릿 해주면 자동으로 command가 리스트 형식으로 입력됨
  stack(command)
  #stack을 구동할 예정임
# Out:
# 14
# push 1
# push 2
# top
# 2
# size
# 2
# empty
# 0
# pop
# 2
# pop
# 1
# pop
# -1
# size
# 0
# empty
# 1
# pop
# -1
# push 3
# empty
# 0
# top
# 3

# %%
#오빠한테 칠 장난

eat = input("쉬는시간 입니까?")

if eat == 'yes':
  misugaru = input("미숫가루를 먹겠습니까?")
  if misugaru == 'no':
    protein = input("단백질 쉐이크를 먹겠습니까?")
    if protein == 'yes':
      print("근손실 방지 쪼아!")
    else:
      print("당신은 뭘먹고 사시겠습니까?")
  else:
    print("꿀 도 타서 맛있게 드십시오")

else:
  print("뭘 좀 드십시오")
# Out:
# 쉬는시간 입니까?yes
# 미숫가루를 먹겠습니까?no
# 단백질 쉐이크를 먹겠습니까?no
# 당신은 뭘먹고 사시겠습니까?

# %%
#7.9강사님 코드

def run_cmd_with_stack(cmd):
  #cmd_type = cmd[0]
  if cmd[0] == 'push':
    #num = cmd[1]
    cmd_type, num = cmd

n = int(input())

for i in range(n):
  #"push 2".split() =>["push", "2"]
  #"size".split() =>["size"]
  command = input().split()
  num = 10
  run_cmd_with_stack()
