# %%
#휴일을 위하여

def rest():
  a, b, R = map(int, input("").split())
  #(a,b)는 공사장의 좌표
  #R은 공사장과의 거리
  #(x_i, y_i) 는 그늘
  #i = N이자 그늘의 갯수
  N = int(input(""))
  for i in range(N):
    x, y = map(int, input("").split())
    #map(int(input(""))) ->아님?
    
      
    if ((x-a)**2) + ((y-b)**2) >= R**2:
      #원을 구하는 공식으로도 사용, 공원 및  공사장은 대충 원으로 이루어져 있나봄.
      print('silent')
    else:
      print('noisy')

# %%
rest()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-53263250fbb6> in <module>()
# ----> 1 rest()
#
# <ipython-input-36-9e9b3b68bf2a> in rest()
#       2
#       3 def rest():
# ----> 4   a, b, R = map(int, input("").split())
#       5   #(a,b)는 공사장의 좌표
#       6   #R은 공사장과의 거리
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %%
 #fail code

def rest():
  
  a = int(input("x좌표 :"))
  b = int(input("y좌표 :"))
  R = int(input("R좌표 :"))

  if ((x-a)**2) + ((y-b)**2) >= R**2:
    print(silent)
  else:
    print(noisy)

print(rest())

# %%
#test

def rest():
  a, b, R = map(int, input("").split())
  #(a,b)는 공사장의 좌표
  #R은 공사장과의 거리
  #(x_i, y_i) 는 그늘
  #i = N이자 그늘의 갯수
  N = int(input(""))
  for i in range(N):
    x, y = map(int, input("").split())
    #map(int(input(""))) ->아님?
    
    while True:
      if ((x-a)**2) + ((y-b)**2) >= R**2:
      #원을 구하는 공식으로도 사용, 공원 및  공사장은 대충 원으로 이루어져 있나봄.
        print('silent')
      elif ((x-a)**2) + ((y-b)**2) <= R**2:
        print('noisy')
      elif i <= N:
        break

# %%
rest()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# noisy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-53263250fbb6> in <module>()
# ----> 1 rest()
#
# <ipython-input-49-f301c0430393> in rest()
#      17         print('silent')
#      18       elif ((x-a)**2) + ((y-b)**2) <= R**2:
# ---> 19         print('noisy')
#      20       elif i <= N:
#      21         break
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     198         If the thread is not running, call immediately.
#     199         """
# --> 200         if self.thread.is_alive():
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
#
# /usr/lib/python3.7/threading.py in is_alive(self)
#    1101         if self._is_stopped or not self._started.is_set():
#    1102             return False
# -> 1103         self._wait_for_tstate_lock(False)
#    1104         return not self._is_stopped
#    1105
#
# /usr/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %%
#인터넷 예문

def check_sound_status(a, b, r, x, y) :
    if (x-a)**2 + (y-b)**2 >= r**2 :
        return "silent"
    return "noisy"

a, b, r = map(int, input().split())
n = int(input())

for i in range (n) :
    x, y = map(int, input().split())
    print(check_sound_status(a, b, r, x, y))
# Out:
# 20 10 10
# 3
# 25 10
# noisy
# 15 10
# noisy
# 70 70
# silent

# %%
#마지막으로 다시 한 번 코드 짜보기
def rest():

  a, b, R = map(int, input("").split())
  N = int(input(""))

  for i in range(N):
    x, y = map(int, input("").split())
    if (x-a)**2 + (y-b)**2 >= R**2:
      print('Silent')
    else:
      print('Noisy')

# %%
rest()
# Out:
# 20 10 10
# 3
# 25 10
# Noisy
# 20 15
# Noisy
# 70 70
# Silent
